# %% [markdown]
# # 2D Dists continued!
#
# ## Pandas styling for tables!
#
# What if instead of having a ton of data to bin, we simply have a 2D table in pandas?

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.normal(size=(6,6)), columns=[x for x in "ABCDEF"])
df
# Out:
#           A         B         C         D         E         F
# 0  0.959399  1.906309 -1.582786  0.357263 -1.169795 -1.825135
# 1 -0.099960 -2.267142  0.669511  0.660943 -0.780010 -0.985384
# 2 -0.581041 -3.069020 -0.128744 -1.523578 -1.363271 -1.468131
# 3  0.386257  1.670472  1.734434 -0.727170  0.199966 -0.095476
# 4  2.652618 -0.512178  0.888298  0.077297  1.826330  1.137091
# 5  1.744322  2.264327  1.456638 -1.695572 -0.389136  0.905485

# %%
def neg_red(x):
    return f"color: {'red' if x < 0 else 'white'}"
df.style.applymap(neg_red)
# Out:
# <style type="text/css">
# #T_d4dc1_row0_col0, #T_d4dc1_row0_col1, #T_d4dc1_row0_col3, #T_d4dc1_row1_col2, #T_d4dc1_row1_col3, #T_d4dc1_row3_col0, #T_d4dc1_row3_col1, #T_d4dc1_row3_col2, #T_d4dc1_row3_col4, #T_d4dc1_row4_col0, #T_d4dc1_row4_col2, #T_d4dc1_row4_col3, #T_d4dc1_row4_col4, #T_d4dc1_row4_col5, #T_d4dc1_row5_col0, #T_d4dc1_row5_col1, #T_d4dc1_row5_col2, #T_d4dc1_row5_col5 {
#   color: white;
# }
# #T_d4dc1_row0_col2, #T_d4dc1_row0_col4, #T_d4dc1_row0_col5, #T_d4dc1_row1_col0, #T_d4dc1_row1_col1, #T_d4dc1_row1_col4, #T_d4dc1_row1_col5, #T_d4dc1_row2_col0, #T_d4dc1_row2_col1, #T_d4dc1_row2_col2, #T_d4dc1_row2_col3, #T_d4dc1_row2_col4, #T_d4dc1_row2_col5, #T_d4dc1_row3_col3, #T_d4dc1_row3_col5, #T_d4dc1_row4_col1, #T_d4dc1_row5_col3, #T_d4dc1_row5_col4 {
#   color: red;
# }
# </style>
# <table id="T_d4dc1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4dc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4dc1_row0_col0" class="data row0 col0" >0.959399</td>
#       <td id="T_d4dc1_row0_col1" class="data row0 col1" >1.906309</td>
#       <td id="T_d4dc1_row0_col2" class="data row0 col2" >-1.582786</td>
#       <td id="T_d4dc1_row0_col3" class="data row0 col3" >0.357263</td>
#       <td id="T_d4dc1_row0_col4" class="data row0 col4" >-1.169795</td>
#       <td id="T_d4dc1_row0_col5" class="data row0 col5" >-1.825135</td>
#     </tr>
#     <tr>
#       <th id="T_d4dc1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4dc1_row1_col0" class="data row1 col0" >-0.099960</td>
#       <td id="T_d4dc1_row1_col1" class="data row1 col1" >-2.267142</td>
#       <td id="T_d4dc1_row1_col2" class="data row1 col2" >0.669511</td>
#       <td id="T_d4dc1_row1_col3" class="data row1 col3" >0.660943</td>
#       <td id="T_d4dc1_row1_col4" class="data row1 col4" >-0.780010</td>
#       <td id="T_d4dc1_row1_col5" class="data row1 col5" >-0.985384</td>
#     </tr>
#     <tr>
#       <th id="T_d4dc1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d4dc1_row2_col0" class="data row2 col0" >-0.581041</td>
#       <td id="T_d4dc1_row2_col1" class="data row2 col1" >-3.069020</td>
#       <td id="T_d4dc1_row2_col2" class="data row2 col2" >-0.128744</td>
#       <td id="T_d4dc1_row2_col3" class="data row2 col3" >-1.523578</td>
#       <td id="T_d4dc1_row2_col4" class="data row2 col4" >-1.363271</td>
#       <td id="T_d4dc1_row2_col5" class="data row2 col5" >-1.468131</td>
#     </tr>
#     <tr>
#       <th id="T_d4dc1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d4dc1_row3_col0" class="data row3 col0" >0.386257</td>
#       <td id="T_d4dc1_row3_col1" class="data row3 col1" >1.670472</td>
#       <td id="T_d4dc1_row3_col2" class="data row3 col2" >1.734434</td>
#       <td id="T_d4dc1_row3_col3" class="data row3 col3" >-0.727170</td>
#       <td id="T_d4dc1_row3_col4" class="data row3 col4" >0.199966</td>
#       <td id="T_d4dc1_row3_col5" class="data row3 col5" >-0.095476</td>
#     </tr>
#     <tr>
#       <th id="T_d4dc1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d4dc1_row4_col0" class="data row4 col0" >2.652618</td>
#       <td id="T_d4dc1_row4_col1" class="data row4 col1" >-0.512178</td>
#       <td id="T_d4dc1_row4_col2" class="data row4 col2" >0.888298</td>
#       <td id="T_d4dc1_row4_col3" class="data row4 col3" >0.077297</td>
#       <td id="T_d4dc1_row4_col4" class="data row4 col4" >1.826330</td>
#       <td id="T_d4dc1_row4_col5" class="data row4 col5" >1.137091</td>
#     </tr>
#     <tr>
#       <th id="T_d4dc1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d4dc1_row5_col0" class="data row5 col0" >1.744322</td>
#       <td id="T_d4dc1_row5_col1" class="data row5 col1" >2.264327</td>
#       <td id="T_d4dc1_row5_col2" class="data row5 col2" >1.456638</td>
#       <td id="T_d4dc1_row5_col3" class="data row5 col3" >-1.695572</td>
#       <td id="T_d4dc1_row5_col4" class="data row5 col4" >-0.389136</td>
#       <td id="T_d4dc1_row5_col5" class="data row5 col5" >0.905485</td>
#     </tr>
#   </tbody>
# </table>

# %%
def gold_max(xs):
    m = xs.to_numpy().max()
    color = {True: "background-color: #c78f2e", False: ""}
    is_max = (xs == m).replace(color)
    return is_max
# By column
df.style.apply(gold_max, axis=0)
# Out:
# <style type="text/css">
# #T_c6eae_row1_col3, #T_c6eae_row3_col2, #T_c6eae_row4_col0, #T_c6eae_row4_col4, #T_c6eae_row4_col5, #T_c6eae_row5_col1 {
#   background-color: #c78f2e;
# }
# </style>
# <table id="T_c6eae_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6eae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6eae_row0_col0" class="data row0 col0" >0.959399</td>
#       <td id="T_c6eae_row0_col1" class="data row0 col1" >1.906309</td>
#       <td id="T_c6eae_row0_col2" class="data row0 col2" >-1.582786</td>
#       <td id="T_c6eae_row0_col3" class="data row0 col3" >0.357263</td>
#       <td id="T_c6eae_row0_col4" class="data row0 col4" >-1.169795</td>
#       <td id="T_c6eae_row0_col5" class="data row0 col5" >-1.825135</td>
#     </tr>
#     <tr>
#       <th id="T_c6eae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6eae_row1_col0" class="data row1 col0" >-0.099960</td>
#       <td id="T_c6eae_row1_col1" class="data row1 col1" >-2.267142</td>
#       <td id="T_c6eae_row1_col2" class="data row1 col2" >0.669511</td>
#       <td id="T_c6eae_row1_col3" class="data row1 col3" >0.660943</td>
#       <td id="T_c6eae_row1_col4" class="data row1 col4" >-0.780010</td>
#       <td id="T_c6eae_row1_col5" class="data row1 col5" >-0.985384</td>
#     </tr>
#     <tr>
#       <th id="T_c6eae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c6eae_row2_col0" class="data row2 col0" >-0.581041</td>
#       <td id="T_c6eae_row2_col1" class="data row2 col1" >-3.069020</td>
#       <td id="T_c6eae_row2_col2" class="data row2 col2" >-0.128744</td>
#       <td id="T_c6eae_row2_col3" class="data row2 col3" >-1.523578</td>
#       <td id="T_c6eae_row2_col4" class="data row2 col4" >-1.363271</td>
#       <td id="T_c6eae_row2_col5" class="data row2 col5" >-1.468131</td>
#     </tr>
#     <tr>
#       <th id="T_c6eae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c6eae_row3_col0" class="data row3 col0" >0.386257</td>
#       <td id="T_c6eae_row3_col1" class="data row3 col1" >1.670472</td>
#       <td id="T_c6eae_row3_col2" class="data row3 col2" >1.734434</td>
#       <td id="T_c6eae_row3_col3" class="data row3 col3" >-0.727170</td>
#       <td id="T_c6eae_row3_col4" class="data row3 col4" >0.199966</td>
#       <td id="T_c6eae_row3_col5" class="data row3 col5" >-0.095476</td>
#     </tr>
#     <tr>
#       <th id="T_c6eae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c6eae_row4_col0" class="data row4 col0" >2.652618</td>
#       <td id="T_c6eae_row4_col1" class="data row4 col1" >-0.512178</td>
#       <td id="T_c6eae_row4_col2" class="data row4 col2" >0.888298</td>
#       <td id="T_c6eae_row4_col3" class="data row4 col3" >0.077297</td>
#       <td id="T_c6eae_row4_col4" class="data row4 col4" >1.826330</td>
#       <td id="T_c6eae_row4_col5" class="data row4 col5" >1.137091</td>
#     </tr>
#     <tr>
#       <th id="T_c6eae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c6eae_row5_col0" class="data row5 col0" >1.744322</td>
#       <td id="T_c6eae_row5_col1" class="data row5 col1" >2.264327</td>
#       <td id="T_c6eae_row5_col2" class="data row5 col2" >1.456638</td>
#       <td id="T_c6eae_row5_col3" class="data row5 col3" >-1.695572</td>
#       <td id="T_c6eae_row5_col4" class="data row5 col4" >-0.389136</td>
#       <td id="T_c6eae_row5_col5" class="data row5 col5" >0.905485</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Entire table
df.style.apply(gold_max, axis=None)
# Out:
# <style type="text/css">
# #T_75ce4_row4_col0 {
#   background-color: #c78f2e;
# }
# </style>
# <table id="T_75ce4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75ce4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75ce4_row0_col0" class="data row0 col0" >0.959399</td>
#       <td id="T_75ce4_row0_col1" class="data row0 col1" >1.906309</td>
#       <td id="T_75ce4_row0_col2" class="data row0 col2" >-1.582786</td>
#       <td id="T_75ce4_row0_col3" class="data row0 col3" >0.357263</td>
#       <td id="T_75ce4_row0_col4" class="data row0 col4" >-1.169795</td>
#       <td id="T_75ce4_row0_col5" class="data row0 col5" >-1.825135</td>
#     </tr>
#     <tr>
#       <th id="T_75ce4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75ce4_row1_col0" class="data row1 col0" >-0.099960</td>
#       <td id="T_75ce4_row1_col1" class="data row1 col1" >-2.267142</td>
#       <td id="T_75ce4_row1_col2" class="data row1 col2" >0.669511</td>
#       <td id="T_75ce4_row1_col3" class="data row1 col3" >0.660943</td>
#       <td id="T_75ce4_row1_col4" class="data row1 col4" >-0.780010</td>
#       <td id="T_75ce4_row1_col5" class="data row1 col5" >-0.985384</td>
#     </tr>
#     <tr>
#       <th id="T_75ce4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75ce4_row2_col0" class="data row2 col0" >-0.581041</td>
#       <td id="T_75ce4_row2_col1" class="data row2 col1" >-3.069020</td>
#       <td id="T_75ce4_row2_col2" class="data row2 col2" >-0.128744</td>
#       <td id="T_75ce4_row2_col3" class="data row2 col3" >-1.523578</td>
#       <td id="T_75ce4_row2_col4" class="data row2 col4" >-1.363271</td>
#       <td id="T_75ce4_row2_col5" class="data row2 col5" >-1.468131</td>
#     </tr>
#     <tr>
#       <th id="T_75ce4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75ce4_row3_col0" class="data row3 col0" >0.386257</td>
#       <td id="T_75ce4_row3_col1" class="data row3 col1" >1.670472</td>
#       <td id="T_75ce4_row3_col2" class="data row3 col2" >1.734434</td>
#       <td id="T_75ce4_row3_col3" class="data row3 col3" >-0.727170</td>
#       <td id="T_75ce4_row3_col4" class="data row3 col4" >0.199966</td>
#       <td id="T_75ce4_row3_col5" class="data row3 col5" >-0.095476</td>
#     </tr>
#     <tr>
#       <th id="T_75ce4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_75ce4_row4_col0" class="data row4 col0" >2.652618</td>
#       <td id="T_75ce4_row4_col1" class="data row4 col1" >-0.512178</td>
#       <td id="T_75ce4_row4_col2" class="data row4 col2" >0.888298</td>
#       <td id="T_75ce4_row4_col3" class="data row4 col3" >0.077297</td>
#       <td id="T_75ce4_row4_col4" class="data row4 col4" >1.826330</td>
#       <td id="T_75ce4_row4_col5" class="data row4 col5" >1.137091</td>
#     </tr>
#     <tr>
#       <th id="T_75ce4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_75ce4_row5_col0" class="data row5 col0" >1.744322</td>
#       <td id="T_75ce4_row5_col1" class="data row5 col1" >2.264327</td>
#       <td id="T_75ce4_row5_col2" class="data row5 col2" >1.456638</td>
#       <td id="T_75ce4_row5_col3" class="data row5 col3" >-1.695572</td>
#       <td id="T_75ce4_row5_col4" class="data row5 col4" >-0.389136</td>
#       <td id="T_75ce4_row5_col5" class="data row5 col5" >0.905485</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.background_gradient(cmap="magma")
# Out:
# <style type="text/css">
# #T_c991e_row0_col0 {
#   background-color: #ab337c;
#   color: #f1f1f1;
# }
# #T_c991e_row0_col1 {
#   background-color: #fddea0;
#   color: #000000;
# }
# #T_c991e_row0_col2, #T_c991e_row0_col5, #T_c991e_row2_col0, #T_c991e_row2_col1, #T_c991e_row2_col4, #T_c991e_row5_col3 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_c991e_row0_col3 {
#   background-color: #fec287;
#   color: #000000;
# }
# #T_c991e_row0_col4 {
#   background-color: #090720;
#   color: #f1f1f1;
# }
# #T_c991e_row1_col0, #T_c991e_row1_col1 {
#   background-color: #251255;
#   color: #f1f1f1;
# }
# #T_c991e_row1_col2 {
#   background-color: #f3655c;
#   color: #f1f1f1;
# }
# #T_c991e_row1_col3, #T_c991e_row3_col2, #T_c991e_row4_col0, #T_c991e_row4_col4, #T_c991e_row4_col5, #T_c991e_row5_col1 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_c991e_row1_col4 {
#   background-color: #331067;
#   color: #f1f1f1;
# }
# #T_c991e_row1_col5 {
#   background-color: #5d177f;
#   color: #f1f1f1;
# }
# #T_c991e_row2_col2 {
#   background-color: #9c2e7f;
#   color: #f1f1f1;
# }
# #T_c991e_row2_col3 {
#   background-color: #0c0926;
#   color: #f1f1f1;
# }
# #T_c991e_row2_col5 {
#   background-color: #1a1042;
#   color: #f1f1f1;
# }
# #T_c991e_row3_col0 {
#   background-color: #641a80;
#   color: #f1f1f1;
# }
# #T_c991e_row3_col1 {
#   background-color: #feca8d;
#   color: #000000;
# }
# #T_c991e_row3_col3 {
#   background-color: #912b81;
#   color: #f1f1f1;
# }
# #T_c991e_row3_col4 {
#   background-color: #b2357b;
#   color: #f1f1f1;
# }
# #T_c991e_row3_col5 {
#   background-color: #d8456c;
#   color: #f1f1f1;
# }
# #T_c991e_row4_col1 {
#   background-color: #ad347c;
#   color: #f1f1f1;
# }
# #T_c991e_row4_col2 {
#   background-color: #fb8560;
#   color: #f1f1f1;
# }
# #T_c991e_row4_col3 {
#   background-color: #fc8961;
#   color: #f1f1f1;
# }
# #T_c991e_row5_col0 {
#   background-color: #f9795d;
#   color: #f1f1f1;
# }
# #T_c991e_row5_col2 {
#   background-color: #fed799;
#   color: #000000;
# }
# #T_c991e_row5_col4 {
#   background-color: #671b80;
#   color: #f1f1f1;
# }
# #T_c991e_row5_col5 {
#   background-color: #fed89a;
#   color: #000000;
# }
# </style>
# <table id="T_c991e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c991e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c991e_row0_col0" class="data row0 col0" >0.959399</td>
#       <td id="T_c991e_row0_col1" class="data row0 col1" >1.906309</td>
#       <td id="T_c991e_row0_col2" class="data row0 col2" >-1.582786</td>
#       <td id="T_c991e_row0_col3" class="data row0 col3" >0.357263</td>
#       <td id="T_c991e_row0_col4" class="data row0 col4" >-1.169795</td>
#       <td id="T_c991e_row0_col5" class="data row0 col5" >-1.825135</td>
#     </tr>
#     <tr>
#       <th id="T_c991e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c991e_row1_col0" class="data row1 col0" >-0.099960</td>
#       <td id="T_c991e_row1_col1" class="data row1 col1" >-2.267142</td>
#       <td id="T_c991e_row1_col2" class="data row1 col2" >0.669511</td>
#       <td id="T_c991e_row1_col3" class="data row1 col3" >0.660943</td>
#       <td id="T_c991e_row1_col4" class="data row1 col4" >-0.780010</td>
#       <td id="T_c991e_row1_col5" class="data row1 col5" >-0.985384</td>
#     </tr>
#     <tr>
#       <th id="T_c991e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c991e_row2_col0" class="data row2 col0" >-0.581041</td>
#       <td id="T_c991e_row2_col1" class="data row2 col1" >-3.069020</td>
#       <td id="T_c991e_row2_col2" class="data row2 col2" >-0.128744</td>
#       <td id="T_c991e_row2_col3" class="data row2 col3" >-1.523578</td>
#       <td id="T_c991e_row2_col4" class="data row2 col4" >-1.363271</td>
#       <td id="T_c991e_row2_col5" class="data row2 col5" >-1.468131</td>
#     </tr>
#     <tr>
#       <th id="T_c991e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c991e_row3_col0" class="data row3 col0" >0.386257</td>
#       <td id="T_c991e_row3_col1" class="data row3 col1" >1.670472</td>
#       <td id="T_c991e_row3_col2" class="data row3 col2" >1.734434</td>
#       <td id="T_c991e_row3_col3" class="data row3 col3" >-0.727170</td>
#       <td id="T_c991e_row3_col4" class="data row3 col4" >0.199966</td>
#       <td id="T_c991e_row3_col5" class="data row3 col5" >-0.095476</td>
#     </tr>
#     <tr>
#       <th id="T_c991e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c991e_row4_col0" class="data row4 col0" >2.652618</td>
#       <td id="T_c991e_row4_col1" class="data row4 col1" >-0.512178</td>
#       <td id="T_c991e_row4_col2" class="data row4 col2" >0.888298</td>
#       <td id="T_c991e_row4_col3" class="data row4 col3" >0.077297</td>
#       <td id="T_c991e_row4_col4" class="data row4 col4" >1.826330</td>
#       <td id="T_c991e_row4_col5" class="data row4 col5" >1.137091</td>
#     </tr>
#     <tr>
#       <th id="T_c991e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c991e_row5_col0" class="data row5 col0" >1.744322</td>
#       <td id="T_c991e_row5_col1" class="data row5 col1" >2.264327</td>
#       <td id="T_c991e_row5_col2" class="data row5 col2" >1.456638</td>
#       <td id="T_c991e_row5_col3" class="data row5 col3" >-1.695572</td>
#       <td id="T_c991e_row5_col4" class="data row5 col4" >-0.389136</td>
#       <td id="T_c991e_row5_col5" class="data row5 col5" >0.905485</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.abs().style.bar(align="left", width=90)
# Out:
# <style type="text/css">
# #T_a7a0c_row0_col0, #T_a7a0c_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 30.3%, transparent 30.3%);
# }
# #T_a7a0c_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 49.1%, transparent 49.1%);
# }
# #T_a7a0c_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 81.5%, transparent 81.5%);
# }
# #T_a7a0c_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.6%, transparent 15.6%);
# }
# #T_a7a0c_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 53.7%, transparent 53.7%);
# }
# #T_a7a0c_row0_col5, #T_a7a0c_row2_col1, #T_a7a0c_row3_col2, #T_a7a0c_row4_col0, #T_a7a0c_row4_col4, #T_a7a0c_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
# }
# #T_a7a0c_row1_col0, #T_a7a0c_row2_col2, #T_a7a0c_row3_col4, #T_a7a0c_row3_col5, #T_a7a0c_row4_col1, #T_a7a0c_row4_col3 {
#   width: 10em;
#   height: 80%;
# }
# #T_a7a0c_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 61.8%, transparent 61.8%);
# }
# #T_a7a0c_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.5%, transparent 32.5%);
# }
# #T_a7a0c_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 32.1%, transparent 32.1%);
# }
# #T_a7a0c_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 46.3%, transparent 46.3%);
# }
# #T_a7a0c_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 17.0%, transparent 17.0%);
# }
# #T_a7a0c_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 80.4%, transparent 80.4%);
# }
# #T_a7a0c_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 64.4%, transparent 64.4%);
# }
# #T_a7a0c_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 71.4%, transparent 71.4%);
# }
# #T_a7a0c_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.1%, transparent 10.1%);
# }
# #T_a7a0c_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 40.8%, transparent 40.8%);
# }
# #T_a7a0c_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 36.1%, transparent 36.1%);
# }
# #T_a7a0c_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 42.6%, transparent 42.6%);
# }
# #T_a7a0c_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 54.2%, transparent 54.2%);
# }
# #T_a7a0c_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 58.0%, transparent 58.0%);
# }
# #T_a7a0c_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 61.7%, transparent 61.7%);
# }
# #T_a7a0c_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 74.4%, transparent 74.4%);
# }
# #T_a7a0c_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.5%, transparent 10.5%);
# }
# #T_a7a0c_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 42.1%, transparent 42.1%);
# }
# </style>
# <table id="T_a7a0c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7a0c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7a0c_row0_col0" class="data row0 col0" >0.959399</td>
#       <td id="T_a7a0c_row0_col1" class="data row0 col1" >1.906309</td>
#       <td id="T_a7a0c_row0_col2" class="data row0 col2" >1.582786</td>
#       <td id="T_a7a0c_row0_col3" class="data row0 col3" >0.357263</td>
#       <td id="T_a7a0c_row0_col4" class="data row0 col4" >1.169795</td>
#       <td id="T_a7a0c_row0_col5" class="data row0 col5" >1.825135</td>
#     </tr>
#     <tr>
#       <th id="T_a7a0c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7a0c_row1_col0" class="data row1 col0" >0.099960</td>
#       <td id="T_a7a0c_row1_col1" class="data row1 col1" >2.267142</td>
#       <td id="T_a7a0c_row1_col2" class="data row1 col2" >0.669511</td>
#       <td id="T_a7a0c_row1_col3" class="data row1 col3" >0.660943</td>
#       <td id="T_a7a0c_row1_col4" class="data row1 col4" >0.780010</td>
#       <td id="T_a7a0c_row1_col5" class="data row1 col5" >0.985384</td>
#     </tr>
#     <tr>
#       <th id="T_a7a0c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a7a0c_row2_col0" class="data row2 col0" >0.581041</td>
#       <td id="T_a7a0c_row2_col1" class="data row2 col1" >3.069020</td>
#       <td id="T_a7a0c_row2_col2" class="data row2 col2" >0.128744</td>
#       <td id="T_a7a0c_row2_col3" class="data row2 col3" >1.523578</td>
#       <td id="T_a7a0c_row2_col4" class="data row2 col4" >1.363271</td>
#       <td id="T_a7a0c_row2_col5" class="data row2 col5" >1.468131</td>
#     </tr>
#     <tr>
#       <th id="T_a7a0c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a7a0c_row3_col0" class="data row3 col0" >0.386257</td>
#       <td id="T_a7a0c_row3_col1" class="data row3 col1" >1.670472</td>
#       <td id="T_a7a0c_row3_col2" class="data row3 col2" >1.734434</td>
#       <td id="T_a7a0c_row3_col3" class="data row3 col3" >0.727170</td>
#       <td id="T_a7a0c_row3_col4" class="data row3 col4" >0.199966</td>
#       <td id="T_a7a0c_row3_col5" class="data row3 col5" >0.095476</td>
#     </tr>
#     <tr>
#       <th id="T_a7a0c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a7a0c_row4_col0" class="data row4 col0" >2.652618</td>
#       <td id="T_a7a0c_row4_col1" class="data row4 col1" >0.512178</td>
#       <td id="T_a7a0c_row4_col2" class="data row4 col2" >0.888298</td>
#       <td id="T_a7a0c_row4_col3" class="data row4 col3" >0.077297</td>
#       <td id="T_a7a0c_row4_col4" class="data row4 col4" >1.826330</td>
#       <td id="T_a7a0c_row4_col5" class="data row4 col5" >1.137091</td>
#     </tr>
#     <tr>
#       <th id="T_a7a0c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a7a0c_row5_col0" class="data row5 col0" >1.744322</td>
#       <td id="T_a7a0c_row5_col1" class="data row5 col1" >2.264327</td>
#       <td id="T_a7a0c_row5_col2" class="data row5 col2" >1.456638</td>
#       <td id="T_a7a0c_row5_col3" class="data row5 col3" >1.695572</td>
#       <td id="T_a7a0c_row5_col4" class="data row5 col4" >0.389136</td>
#       <td id="T_a7a0c_row5_col5" class="data row5 col5" >0.905485</td>
#     </tr>
#   </tbody>
# </table>

# %%
head = {"selector": "th", "props": [("text-align", "center")]}
df.style.set_table_styles([head]).bar(align="mid", color=['red', 'green'], vmin=-3, vmax=3)
# Out:
# <style type="text/css">
# #T_245d1_ th {
#   text-align: center;
# }
# #T_245d1_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 66.0%, transparent 66.0%);
# }
# #T_245d1_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 81.8%, transparent 81.8%);
# }
# #T_245d1_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 23.6%, red 23.6%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 56.0%, transparent 56.0%);
# }
# #T_245d1_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 30.5%, red 30.5%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 19.6%, red 19.6%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 48.3%, red 48.3%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.2%, red 12.2%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 61.2%, transparent 61.2%);
# }
# #T_245d1_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 61.0%, transparent 61.0%);
# }
# #T_245d1_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 37.0%, red 37.0%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 33.6%, red 33.6%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 40.3%, red 40.3%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 50.0%, transparent 50.0%);
# }
# #T_245d1_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 47.9%, red 47.9%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 24.6%, red 24.6%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 27.3%, red 27.3%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 25.5%, red 25.5%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 56.4%, transparent 56.4%);
# }
# #T_245d1_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 77.8%, transparent 77.8%);
# }
# #T_245d1_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 78.9%, transparent 78.9%);
# }
# #T_245d1_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 37.9%, red 37.9%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 53.3%, transparent 53.3%);
# }
# #T_245d1_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 48.4%, red 48.4%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 94.2%, transparent 94.2%);
# }
# #T_245d1_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, red 41.5%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 64.8%, transparent 64.8%);
# }
# #T_245d1_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 51.3%, transparent 51.3%);
# }
# #T_245d1_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 80.4%, transparent 80.4%);
# }
# #T_245d1_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 69.0%, transparent 69.0%);
# }
# #T_245d1_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 79.1%, transparent 79.1%);
# }
# #T_245d1_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 87.7%, transparent 87.7%);
# }
# #T_245d1_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 74.3%, transparent 74.3%);
# }
# #T_245d1_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 21.7%, red 21.7%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 43.5%, red 43.5%, red 50.0%, transparent 50.0%);
# }
# #T_245d1_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 65.1%, transparent 65.1%);
# }
# </style>
# <table id="T_245d1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_245d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_245d1_row0_col0" class="data row0 col0" >0.959399</td>
#       <td id="T_245d1_row0_col1" class="data row0 col1" >1.906309</td>
#       <td id="T_245d1_row0_col2" class="data row0 col2" >-1.582786</td>
#       <td id="T_245d1_row0_col3" class="data row0 col3" >0.357263</td>
#       <td id="T_245d1_row0_col4" class="data row0 col4" >-1.169795</td>
#       <td id="T_245d1_row0_col5" class="data row0 col5" >-1.825135</td>
#     </tr>
#     <tr>
#       <th id="T_245d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_245d1_row1_col0" class="data row1 col0" >-0.099960</td>
#       <td id="T_245d1_row1_col1" class="data row1 col1" >-2.267142</td>
#       <td id="T_245d1_row1_col2" class="data row1 col2" >0.669511</td>
#       <td id="T_245d1_row1_col3" class="data row1 col3" >0.660943</td>
#       <td id="T_245d1_row1_col4" class="data row1 col4" >-0.780010</td>
#       <td id="T_245d1_row1_col5" class="data row1 col5" >-0.985384</td>
#     </tr>
#     <tr>
#       <th id="T_245d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_245d1_row2_col0" class="data row2 col0" >-0.581041</td>
#       <td id="T_245d1_row2_col1" class="data row2 col1" >-3.069020</td>
#       <td id="T_245d1_row2_col2" class="data row2 col2" >-0.128744</td>
#       <td id="T_245d1_row2_col3" class="data row2 col3" >-1.523578</td>
#       <td id="T_245d1_row2_col4" class="data row2 col4" >-1.363271</td>
#       <td id="T_245d1_row2_col5" class="data row2 col5" >-1.468131</td>
#     </tr>
#     <tr>
#       <th id="T_245d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_245d1_row3_col0" class="data row3 col0" >0.386257</td>
#       <td id="T_245d1_row3_col1" class="data row3 col1" >1.670472</td>
#       <td id="T_245d1_row3_col2" class="data row3 col2" >1.734434</td>
#       <td id="T_245d1_row3_col3" class="data row3 col3" >-0.727170</td>
#       <td id="T_245d1_row3_col4" class="data row3 col4" >0.199966</td>
#       <td id="T_245d1_

# %%
# we can chain everything together
df.style.bar(align="mid", width=50).apply(gold_max, axis=None).applymap(neg_red)
# Out:
# <style type="text/css">
# #T_87c85_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 9.0%, #d65f5f 9.0%, #d65f5f 23.8%, transparent 23.8%);
#   color: white;
# }
# #T_87c85_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 28.8%, #d65f5f 28.8%, #d65f5f 46.6%, transparent 46.6%);
#   color: white;
# }
# #T_87c85_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 23.9%, transparent 23.9%);
#   color: red;
# }
# #T_87c85_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 36.0%, #d65f5f 36.0%, #d65f5f 43.6%, transparent 43.6%);
#   color: white;
# }
# #T_87c85_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 3.0%, #d65f5f 3.0%, #d65f5f 21.4%, transparent 21.4%);
#   color: red;
# }
# #T_87c85_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 30.8%, transparent 30.8%);
#   color: red;
# }
# #T_87c85_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.4%, #d65f5f 7.4%, #d65f5f 9.0%, transparent 9.0%);
#   color: red;
# }
# #T_87c85_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.5%, #d65f5f 7.5%, #d65f5f 28.8%, transparent 28.8%);
#   color: red;
# }
# #T_87c85_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 23.9%, #d65f5f 23.9%, #d65f5f 33.9%, transparent 33.9%);
#   color: white;
# }
# #T_87c85_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 36.0%, #d65f5f 36.0%, #d65f5f 50.0%, transparent 50.0%);
#   color: white;
# }
# #T_87c85_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 9.1%, #d65f5f 9.1%, #d65f5f 21.4%, transparent 21.4%);
#   color: red;
# }
# #T_87c85_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.2%, #d65f5f 14.2%, #d65f5f 30.8%, transparent 30.8%);
#   color: red;
# }
# #T_87c85_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.0%, transparent 9.0%);
#   color: red;
# }
# #T_87c85_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 28.8%, transparent 28.8%);
#   color: red;
# }
# #T_87c85_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 21.9%, #d65f5f 21.9%, #d65f5f 23.9%, transparent 23.9%);
#   color: red;
# }
# #T_87c85_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 3.6%, #d65f5f 3.6%, #d65f5f 36.0%, transparent 36.0%);
#   color: red;
# }
# #T_87c85_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.4%, transparent 21.4%);
#   color: red;
# }
# #T_87c85_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 6.0%, #d65f5f 6.0%, #d65f5f 30.8%, transparent 30.8%);
#   color: red;
# }
# #T_87c85_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 9.0%, #d65f5f 9.0%, #d65f5f 15.0%, transparent 15.0%);
#   color: white;
# }
# #T_87c85_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 28.8%, #d65f5f 28.8%, #d65f5f 44.4%, transparent 44.4%);
#   color: white;
# }
# #T_87c85_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 23.9%, #d65f5f 23.9%, #d65f5f 50.0%, transparent 50.0%);
#   color: white;
# }
# #T_87c85_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 20.5%, #d65f5f 20.5%, #d65f5f 36.0%, transparent 36.0%);
#   color: red;
# }
# #T_87c85_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 21.4%, #d65f5f 21.4%, #d65f5f 24.5%, transparent 24.5%);
#   color: white;
# }
# #T_87c85_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 29.2%, #d65f5f 29.2%, #d65f5f 30.8%, transparent 30.8%);
#   color: red;
# }
# #T_87c85_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 9.0%, #d65f5f 9.0%, #d65f5f 50.0%, transparent 50.0%);
#   background-color: #c78f2e;
#   color: white;
# }
# #T_87c85_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 24.0%, #d65f5f 24.0%, #d65f5f 28.8%, transparent 28.8%);
#   color: red;
# }
# #T_87c85_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 23.9%, #d65f5f 23.9%, #d65f5f 37.2%, transparent 37.2%);
#   color: white;
# }
# #T_87c85_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 36.0%, #d65f5f 36.0%, #d65f5f 37.6%, transparent 37.6%);
#   color: white;
# }
# #T_87c85_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 21.4%, #d65f5f 21.4%, #d65f5f 50.0%, transparent 50.0%);
#   color: white;
# }
# #T_87c85_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 30.8%, #d65f5f 30.8%, #d65f5f 50.0%, transparent 50.0%);
#   color: white;
# }
# #T_87c85_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 9.0%, #d65f5f 9.0%, #d65f5f 36.0%, transparent 36.0%);
#   color: white;
# }
# #T_87c85_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 28.8%, #d65f5f 28.8%, #d65f5f 50.0%, transparent 50.0%);
#   color: white;
# }
# #T_87c85_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 23.9%, #d65f5f 23.9%, #d65f5f 45.8%, transparent 45.8%);
#   color: white;
# }
# #T_87c85_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 36.0%, transparent 36.0%);
#   color: red;
# }
# #T_87c85_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 15.3%, #d65f5f 15.3%, #d65f5f 21.4%, transparent 21.4%);
#   color: red;
# }
# #T_87c85_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 30.8%, #d65f5f 30.8%, #d65f5f 46.1%, transparent 46.1%);
#   color: white;
# }
# </style>
# <table id="T_87c85_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87c85_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87c85_row0_col0" class="data row0 col0" >0.959399</td>
#       <td id="T_87c85_row0_col1" class="data row0 col1" >1.906309</td>
#       <td id="T_87c85_row0_col2" class="data row0 col2" >-1.582786</td>
#       <td id="T_87c85_row0_col3" class="data row0 col3" >0.357263</td>
#       <td id="T_87c85_row0_col4" class="data row0 col4" >-1.169795</td>
#       <td id="T_87c85_row0_col5" class="data row0 col5" >-1.825135</td>
#     </tr>
#     <tr>
#       <th id="T_87c85_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87c85_row1_col0" class="data row1 col0" >-0.099960</td>
#       <td id="T_87c85_row1_col1" class="data row1 col1" >-2.267142</td>
#       <td id="T_87c85_row1_col2" class="data row1 col2" >0.669511</td>
#       <td id="T_87c85_row1_col3" class="data row1 col3" >0.660943</td>
#       <td id="T_87c85_row1_col4" class="data row1 col4" >-0.780010</td>
#       <td id="T_87c85_row1_col5" class="data row1 col5" >-0.985384</td>
#     </tr>
#     <tr>
#       <th id="T_87c85_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_87c85_row2_col0" class="data row2 col0" >-0.581041</td>
#       <td id="T_87c85_row2_col1" class="data row2 col1" >-3.069020</td>
#       <td id="T_87c85_row2_col2" class="data row2 col2" >-0.128744</td>
#       <td id="T_87c85_row2_col3" class="data row2 col3" >-1.523578</td>
#       <td id="T_87c85_row2_col4" class="data row2 col4" >-1.363271</td>
